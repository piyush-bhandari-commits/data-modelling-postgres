# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:student@127.0.0.1/sparkifydb

# %%
# %sql SELECT * FROM pg_stat_activity
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 7 rows affected.
# [(None, None, 285, None, None, None, '', None, None, None, datetime.datetime(2020, 11, 16, 11, 17, 22, 936578, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'AutoVacuumMain', None, None, None, '', 'autovacuum launcher'),
#  (None, None, 287, None, 10, 'postgres', '', None, None, None, datetime.datetime(2020, 11, 16, 11, 17, 22, 941117, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'LogicalLauncherMain', None, None, None, '', 'logical replication launcher'),
#  (16548, 'sparkifydb', 4700, None, 10, 'postgres', '', '127.0.0.1', None, 51348, datetime.datetime(2020, 11, 17, 14, 13, 46, 153851, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, datetime.datetime(2020, 11, 17, 14, 13, 46, 177435, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), 'Client', 'ClientRead', 'idle', None, None, '', 'client backend'),
#  (16548, 'sparkifydb', 7186, None, 10, 'postgres', '', '127.0.0.1', None, 52494, datetime.datetime(2020, 11, 17, 16, 42, 0, 681009, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), datetime.datetime(2020, 11, 17, 16, 42, 0, 830660, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), datetime.datetime(2020, 11, 17, 16, 42, 0, 830836, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), datetime.datetime(2020, 11, 17, 16, 42, 0, 830837, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, 'active', None, '580', 'SELECT * FROM pg_stat_activity', 'client backend'),
#  (None, None, 283, None, None, None, '', None, None, None, datetime.datetime(2020, 11, 16, 11, 17, 22, 928501, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'BgWriterMain', None, None, None, '', 'background writer'),
#  (None, None, 282, None, None, None, '', None, None, None, datetime.datetime(2020, 11, 16, 11, 17, 22, 927180, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'CheckpointerMain', None, None, None, '', 'checkpointer'),
#  (None, None, 284, None, None, None, '', None, None, None, datetime.datetime(2020, 11, 16, 11, 17, 22, 930403, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'WalWriterMain', None, None, None, '', 'walwriter')]

# %%
# %sql SELECT * FROM artists;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM songs;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM time;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM songplays;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM users;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []
