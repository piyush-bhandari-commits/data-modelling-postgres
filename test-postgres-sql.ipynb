# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:student@127.0.0.1/sparkifydb

# %%
# %sql SELECT * FROM pg_stat_activity
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 8 rows affected.
# [(None, None, 4063, None, None, None, '', None, None, None, datetime.datetime(2020, 11, 12, 16, 8, 39, 234992, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'AutoVacuumMain', None, None, None, '', 'autovacuum launcher'),
#  (None, None, 4065, None, 10, 'postgres', '', None, None, None, datetime.datetime(2020, 11, 12, 16, 8, 39, 236285, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'LogicalLauncherMain', None, None, None, '', 'logical replication launcher'),
#  (16479, 'sparkifydb', 8577, None, 10, 'postgres', '', '127.0.0.1', None, 55347, datetime.datetime(2020, 11, 12, 23, 58, 0, 851085, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, datetime.datetime(2020, 11, 13, 0, 4, 1, 758755, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), datetime.datetime(2020, 11, 13, 0, 4, 1, 758862, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), 'Client', 'ClientRead', 'idle', None, None, 'commit', 'client backend'),
#  (16479, 'sparkifydb', 8467, None, 10, 'postgres', '', '127.0.0.1', None, 55341, datetime.datetime(2020, 11, 12, 23, 56, 59, 281885, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, datetime.datetime(2020, 11, 12, 23, 57, 26, 64128, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), datetime.datetime(2020, 11, 12, 23, 57, 26, 64401, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), 'Client', 'ClientRead', 'idle', None, None, 'DROP DATABASE IF EXISTS sparkifydb', 'client backend'),
#  (16479, 'sparkifydb', 9184, None, 10, 'postgres', '', '127.0.0.1', None, 55474, datetime.datetime(2020, 11, 13, 0, 5, 36, 124523, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), datetime.datetime(2020, 11, 13, 0, 5, 49, 71030, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), datetime.datetime(2020, 11, 13, 0, 5, 49, 71499, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), datetime.datetime(2020, 11, 13, 0, 5, 49, 71500, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, 'active', None, '560', 'SELECT * FROM pg_stat_activity', 'client backend'),
#  (None, None, 4061, None, None, None, '', None, None, None, datetime.datetime(2020, 11, 12, 16, 8, 39, 234319, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'BgWriterMain', None, None, None, '', 'background writer'),
#  (None, None, 4060, None, None, None, '', None, None, None, datetime.datetime(2020, 11, 12, 16, 8, 39, 234161, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'CheckpointerMain', None, None, None, '', 'checkpointer'),
#  (None, None, 4062, None, None, None, '', None, None, None, datetime.datetime(2020, 11, 12, 16, 8, 39, 234969, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-300, name=None)), None, None, None, 'Activity', 'WalWriterMain', None, None, None, '', 'walwriter')]

# %%
# %sql SELECT * FROM artists;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan)]

# %%
# %sql SELECT * FROM songs;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233.40363)]

# %%
# %sql SELECT * FROM time;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM songplays;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM users;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []
