# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:student@127.0.0.1:5432/sparkifydb

# %%
# Out:
#  * postgresql://postgres:***@localhost/sparkifydb
# (psycopg2.errors.UndefinedTable) relation "pg_stat_sctivity" does not exist
# LINE 1: SELECT * FROM pg_stat_sctivity
#                       ^
#
# [SQL: SELECT * FROM pg_stat_sctivity]
# (Background on this error at: http://sqlalche.me/e/f405)
